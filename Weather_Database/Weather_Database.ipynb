# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | shetpe
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | prince rupert
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | vanimo
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | pacific grove
# Processing Record 9 of Set 1 | kot addu
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | chuy
# Processing Record 12 of Set 1 | jos
# Processing Record 13 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | inuvik
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | guerrero negro
# Processing Record 18 of Set 1 | bonito
# Processing Record 19 of Set 1 | mackenzie
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | bamora
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | auki
# Processing Record 24 of Set 1 | mayo
# Processing Record 25 of Set 1 | gladstone
# Processing Record 26 of Set 1 | aranos
# Processing Record 27 of Set 1 | port macquarie
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 1 | shamary
# Processing Record 33 of Set 1 | harper
# Processing Record 34 of Set 1 | hamilton
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | ladario
# Processing Record 39 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 1 | berdigestyakh
# Processing Record 41 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 1 | emerald
# Processing Record 43 of Set 1 | puerto del rosario
# Processing Record 44 of Set 1 | umm lajj
# Processing Record 45 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | nome
# Processing Record 48 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | agudos
# Processing Record 1 of Set 2 | aitape
# Processing Record 2 of Set 2 | honiara
# Processing Record 3 of Set 2 | alpena
# Processing Record 4 of Set 2 | olafsvik
# Processing Record 5 of Set 2 | denham springs
# Processing Record 6 of Set 2 | kovdor
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | san juan
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | udachnyy
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | zhigansk
# Processing Record 15 of Set 2 | salamanca
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | timra
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | souillac
# Processing Record 20 of Set 2 | rockhampton
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | cabo san lucas
# Processing Record 23 of Set 2 | ukiah
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | lagoa
# Processing Record 26 of Set 2 | nantucket
# Processing Record 27 of Set 2 | tabuk
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | shubarshi
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | arinos
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | pangody
# Processing Record 41 of Set 2 | calama
# Processing Record 42 of Set 2 | kathmandu
# Processing Record 43 of Set 2 | klaksvik
# Processing Record 44 of Set 2 | college
# Processing Record 45 of Set 2 | adeje
# Processing Record 46 of Set 2 | coihaique
# Processing Record 47 of Set 2 | acapulco
# Processing Record 48 of Set 2 | san cristobal
# Processing Record 49 of Set 2 | altayskoye
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | bambanglipuro
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | santa cruz
# Processing Record 4 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 3 | ancud
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 3 | sterling
# Processing Record 9 of Set 3 | copala
# Processing Record 10 of Set 3 | havoysund
# Processing Record 11 of Set 3 | caravelas
# Processing Record 12 of Set 3 | zabol
# Processing Record 13 of Set 3 | savino
# Processing Record 14 of Set 3 | glenwood springs
# Processing Record 15 of Set 3 | mangan
# Processing Record 16 of Set 3 | ozinki
# Processing Record 17 of Set 3 | codrington
# Processing Record 18 of Set 3 | fuengirola
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | kyzyl-suu
# Processing Record 21 of Set 3 | zhaotong
# Processing Record 22 of Set 3 | dumas
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | chapais
# Processing Record 27 of Set 3 | hovd
# Processing Record 28 of Set 3 | lakes entrance
# Processing Record 29 of Set 3 | turukhansk
# Processing Record 30 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | llandrindod wells
# Processing Record 32 of Set 3 | saldanha
# Processing Record 33 of Set 3 | norman wells
# Processing Record 34 of Set 3 | provideniya
# Processing Record 35 of Set 3 | igarka
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | hakvik
# City not found. Skipping...
# Processing Record 38 of Set 3 | lompoc
# Processing Record 39 of Set 3 | williams lake
# Processing Record 40 of Set 3 | bathsheba
# Processing Record 41 of Set 3 | kahului
# Processing Record 42 of Set 3 | strai
# Processing Record 43 of Set 3 | balsas
# Processing Record 44 of Set 3 | porto novo
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | okoneshnikovo
# Processing Record 47 of Set 3 | coquimbo
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | gat
# Processing Record 50 of Set 3 | worland
# Processing Record 1 of Set 4 | srikakulam
# Processing Record 2 of Set 4 | saint-augustin
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | cayenne
# Processing Record 5 of Set 4 | brookhaven
# Processing Record 6 of Set 4 | dikson
# Processing Record 7 of Set 4 | davenda
# Processing Record 8 of Set 4 | kruje
# Processing Record 9 of Set 4 | karratha
# Processing Record 10 of Set 4 | kodiak
# Processing Record 11 of Set 4 | puerto escondido
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | booue
# Processing Record 14 of Set 4 | nemuro
# Processing Record 15 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 4 | cape town
# Processing Record 17 of Set 4 | aswan
# Processing Record 18 of Set 4 | hithadhoo
# Processing Record 19 of Set 4 | sibolga
# Processing Record 20 of Set 4 | saskylakh
# Processing Record 21 of Set 4 | hofn
# Processing Record 22 of Set 4 | san rafael
# Processing Record 23 of Set 4 | aklavik
# Processing Record 24 of Set 4 | kapaa
# Processing Record 25 of Set 4 | omboue
# Processing Record 26 of Set 4 | nikolskoye
# Processing Record 27 of Set 4 | nago
# Processing Record 28 of Set 4 | siilinjarvi
# Processing Record 29 of Set 4 | gagra
# Processing Record 30 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 4 | brest
# Processing Record 32 of Set 4 | okha
# Processing Record 33 of Set 4 | ostrovnoy
# Processing Record 34 of Set 4 | tavda
# Processing Record 35 of Set 4 | zabaykalsk
# Processing Record 36 of Set 4 | tuktoyaktuk
# Processing Record 37 of Set 4 | san nicolas
# Processing Record 38 of Set 4 | kopayhorod
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | camacupa
# Processing Record 41 of Set 4 | vaini
# Processing Record 42 of Set 4 | naze
# Processing Record 43 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 4 | mahebourg
# Processing Record 45 of Set 4 | linjiang
# Processing Record 46 of Set 4 | pingliang
# Processing Record 47 of Set 4 | ban nahin
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | portland
# Processing Record 50 of Set 4 | east foothills
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | vila
# Processing Record 3 of Set 5 | avera
# Processing Record 4 of Set 5 | saint-philippe
# Processing Record 5 of Set 5 | mana
# Processing Record 6 of Set 5 | carrickmacross
# Processing Record 7 of Set 5 | te anau
# Processing Record 8 of Set 5 | port elizabeth
# Processing Record 9 of Set 5 | upernavik
# Processing Record 10 of Set 5 | talnakh
# Processing Record 11 of Set 5 | broken hill
# Processing Record 12 of Set 5 | moose jaw
# Processing Record 13 of Set 5 | guekedou
# City not found. Skipping...
# Processing Record 14 of Set 5 | sao filipe
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | chernyshevskiy
# Processing Record 17 of Set 5 | fethiye
# Processing Record 18 of Set 5 | singkang
# Processing Record 19 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 5 | istisu
# Processing Record 22 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | yaransk
# Processing Record 24 of Set 5 | phangnga
# Processing Record 25 of Set 5 | bozoum
# Processing Record 26 of Set 5 | vangaindrano
# Processing Record 27 of Set 5 | honningsvag
# Processing Record 28 of Set 5 | hami
# Processing Record 29 of Set 5 | drinovci
# Processing Record 30 of Set 5 | bengkulu
# Processing Record 31 of Set 5 | roald
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | nowogard
# Processing Record 34 of Set 5 | bairiki
# Processing Record 35 of Set 5 | sawakin
# Processing Record 36 of Set 5 | severnyy
# Processing Record 37 of Set 5 | sisimiut
# Processing Record 38 of Set 5 | shagonar
# Processing Record 39 of Set 5 | fortuna
# Processing Record 40 of Set 5 | knysna
# Processing Record 41 of Set 5 | talara
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | chicama
# Processing Record 44 of Set 5 | nouadhibou
# Processing Record 45 of Set 5 | dax
# Processing Record 46 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 47 of Set 5 | plettenberg bay
# Processing Record 48 of Set 5 | grand gaube
# Processing Record 49 of Set 5 | salalah
# Processing Record 50 of Set 5 | barrow
# Processing Record 1 of Set 6 | iqaluit
# Processing Record 2 of Set 6 | fuerte olimpo
# Processing Record 3 of Set 6 | namwala
# Processing Record 4 of Set 6 | beian
# Processing Record 5 of Set 6 | walvis bay
# Processing Record 6 of Set 6 | decines-charpieu
# Processing Record 7 of Set 6 | flin flon
# Processing Record 8 of Set 6 | banda aceh
# Processing Record 9 of Set 6 | agadez
# Processing Record 10 of Set 6 | williamsburg
# Processing Record 11 of Set 6 | diffa
# Processing Record 12 of Set 6 | batagay-alyta
# Processing Record 13 of Set 6 | shahrud
# Processing Record 14 of Set 6 | prince george
# Processing Record 15 of Set 6 | kavaratti
# Processing Record 16 of Set 6 | karasjok
# Processing Record 17 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 6 | atibaia
# Processing Record 19 of Set 6 | port hardy
# Processing Record 20 of Set 6 | cherskiy
# Processing Record 21 of Set 6 | anadyr
# Processing Record 22 of Set 6 | kungurtug
# Processing Record 23 of Set 6 | canning
# Processing Record 24 of Set 6 | shadegan
# Processing Record 25 of Set 6 | saint-pierre
# Processing Record 26 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 6 | malmesbury
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | lata
# Processing Record 30 of Set 6 | dongsheng
# Processing Record 31 of Set 6 | toucheng
# Processing Record 32 of Set 6 | aripuana
# Processing Record 33 of Set 6 | americus
# Processing Record 34 of Set 6 | fort nelson
# Processing Record 35 of Set 6 | torbay
# Processing Record 36 of Set 6 | vila do maio
# Processing Record 37 of Set 6 | vila velha
# Processing Record 38 of Set 6 | praia
# Processing Record 39 of Set 6 | verkhoyansk
# Processing Record 40 of Set 6 | neiafu
# Processing Record 41 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 6 | tomatlan
# Processing Record 43 of Set 6 | dibulla
# Processing Record 44 of Set 6 | luis correia
# Processing Record 45 of Set 6 | olden
# Processing Record 46 of Set 6 | gravdal
# Processing Record 47 of Set 6 | yekaterinovka
# Processing Record 48 of Set 6 | mirina
# City not found. Skipping...
# Processing Record 49 of Set 6 | halifax
# Processing Record 50 of Set 6 | ouallam
# Processing Record 1 of Set 7 | raudeberg
# Processing Record 2 of Set 7 | kudahuvadhoo
# Processing Record 3 of Set 7 | bonfim
# Processing Record 4 of Set 7 | mabaruma
# Processing Record 5 of Set 7 | roebourne
# Processing Record 6 of Set 7 | gari
# Processing Record 7 of Set 7 | faya
# Processing Record 8 of Set 7 | capitao poco
# Processing Record 9 of Set 7 | bar harbor
# Processing Record 10 of Set 7 | puerto penasco
# Processing Record 11 of Set 7 | rameswaram
# Processing Record 12 of Set 7 | coahuayana
# Processing Record 13 of Set 7 | whitehorse
# Processing Record 14 of Set 7 | tateyama
# Processing Record 15 of Set 7 | terney
# Processing Record 16 of Set 7 | kedrovyy
# Processing Record 17 of Set 7 | camacha
# Processing Record 18 of Set 7 | lavrentiya
# Processing Record 19 of Set 7 | dudinka
# Processing Record 20 of Set 7 | leningradskiy
# Processing Record 21 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 7 | yefira
# City not found. Skipping...
# Processing Record 23 of Set 7 | jumla
# Processing Record 24 of Set 7 | jacqueville
# Processing Record 25 of Set 7 | situbondo
# Processing Record 26 of Set 7 | whitecourt
# Processing Record 27 of Set 7 | beringovskiy
# Processing Record 28 of Set 7 | slave lake
# Processing Record 29 of Set 7 | kruisfontein
# Processing Record 30 of Set 7 | birao
# Processing Record 31 of Set 7 | cidreira
# Processing Record 32 of Set 7 | port blair
# Processing Record 33 of Set 7 | severo-kurilsk
# Processing Record 34 of Set 7 | zhitikara
# City not found. Skipping...
# Processing Record 35 of Set 7 | hasaki
# Processing Record 36 of Set 7 | kawalu
# Processing Record 37 of Set 7 | daitari
# Processing Record 38 of Set 7 | lock haven
# Processing Record 39 of Set 7 | novoagansk
# Processing Record 40 of Set 7 | kapit
# Processing Record 41 of Set 7 | pierre
# Processing Record 42 of Set 7 | sitka
# Processing Record 43 of Set 7 | brae
# Processing Record 44 of Set 7 | lamu
# Processing Record 45 of Set 7 | yuanping
# Processing Record 46 of Set 7 | nieves
# Processing Record 47 of Set 7 | zhangjiakou
# Processing Record 48 of Set 7 | marzuq
# Processing Record 49 of Set 7 | alegrete
# Processing Record 50 of Set 7 | haines junction
# Processing Record 1 of Set 8 | juegang
# Processing Record 2 of Set 8 | lazaro cardenas
# Processing Record 3 of Set 8 | san jose
# Processing Record 4 of Set 8 | yerbogachen
# Processing Record 5 of Set 8 | areosa
# Processing Record 6 of Set 8 | tobermory
# Processing Record 7 of Set 8 | ponta do sol
# Processing Record 8 of Set 8 | paamiut
# Processing Record 9 of Set 8 | tucupita
# Processing Record 10 of Set 8 | khudumelapye
# Processing Record 11 of Set 8 | salantai
# Processing Record 12 of Set 8 | muros
# Processing Record 13 of Set 8 | phan thiet
# Processing Record 14 of Set 8 | kibala
# Processing Record 15 of Set 8 | segezha
# Processing Record 16 of Set 8 | iskateley
# Processing Record 17 of Set 8 | alamosa
# Processing Record 18 of Set 8 | aromashevo
# Processing Record 19 of Set 8 | marsa matruh
# Processing Record 20 of Set 8 | kanadey
# Processing Record 21 of Set 8 | rabo de peixe
# Processing Record 22 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 23 of Set 8 | shelburne
# Processing Record 24 of Set 8 | abu dhabi
# Processing Record 25 of Set 8 | pisco
# Processing Record 26 of Set 8 | kavieng
# Processing Record 27 of Set 8 | nishihara
# Processing Record 28 of Set 8 | kimbe
# Processing Record 29 of Set 8 | luderitz
# Processing Record 30 of Set 8 | krasnoselkup
# Processing Record 31 of Set 8 | antsohihy
# Processing Record 32 of Set 8 | bulgan
# Processing Record 33 of Set 8 | sanghar
# Processing Record 34 of Set 8 | abashiri
# Processing Record 35 of Set 8 | tuy hoa
# Processing Record 36 of Set 8 | kashi
# Processing Record 37 of Set 8 | oistins
# Processing Record 38 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 8 | bonnyville
# Processing Record 40 of Set 8 | bonthe
# Processing Record 41 of Set 8 | kanniyakumari
# Processing Record 42 of Set 8 | mindelo
# Processing Record 43 of Set 8 | waitati
# Processing Record 44 of Set 8 | marystown
# Processing Record 45 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 8 | gigmoto
# Processing Record 47 of Set 8 | soskovo
# Processing Record 48 of Set 8 | vostok
# Processing Record 49 of Set 8 | quesnel
# Processing Record 50 of Set 8 | oranjestad
# Processing Record 1 of Set 9 | los llanos de aridane
# Processing Record 2 of Set 9 | russkaya polyana
# Processing Record 3 of Set 9 | yulara
# Processing Record 4 of Set 9 | clyde river
# Processing Record 5 of Set 9 | tanggu
# Processing Record 6 of Set 9 | srandakan
# Processing Record 7 of Set 9 | broome
# Processing Record 8 of Set 9 | boysun
# Processing Record 9 of Set 9 | alofi
# Processing Record 10 of Set 9 | nabire
# Processing Record 11 of Set 9 | bayan
# Processing Record 12 of Set 9 | tazovskiy
# Processing Record 13 of Set 9 | kirakira
# Processing Record 14 of Set 9 | luwuk
# Processing Record 15 of Set 9 | houma
# Processing Record 16 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | mandalgovi
# Processing Record 18 of Set 9 | caluquembe
# Processing Record 19 of Set 9 | faanui
# Processing Record 20 of Set 9 | constantine
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | ambilobe
# Processing Record 23 of Set 9 | oussouye
# Processing Record 24 of Set 9 | northam
# Processing Record 25 of Set 9 | adrar
# Processing Record 26 of Set 9 | atar
# Processing Record 27 of Set 9 | vila franca do campo
# Processing Record 28 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 9 | saint anthony
# Processing Record 30 of Set 9 | longyearbyen
# Processing Record 31 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 9 | half moon bay
# Processing Record 33 of Set 9 | kargopol
# Processing Record 34 of Set 9 | khuzhir
# Processing Record 35 of Set 9 | escondido
# Processing Record 36 of Set 9 | vestmannaeyjar
# Processing Record 37 of Set 9 | mangrol
# Processing Record 38 of Set 9 | sioux lookout
# Processing Record 39 of Set 9 | sargatskoye
# Processing Record 40 of Set 9 | trenggalek
# Processing Record 41 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 9 | zamora
# Processing Record 43 of Set 9 | evensk
# Processing Record 44 of Set 9 | ardakan
# Processing Record 45 of Set 9 | waingapu
# Processing Record 46 of Set 9 | oudtshoorn
# Processing Record 47 of Set 9 | mehamn
# Processing Record 48 of Set 9 | bundaberg
# Processing Record 49 of Set 9 | rosarito
# Processing Record 50 of Set 9 | ligayan
# Processing Record 1 of Set 10 | asosa
# Processing Record 2 of Set 10 | kiunga
# Processing Record 3 of Set 10 | neuquen
# Processing Record 4 of Set 10 | dalbandin
# Processing Record 5 of Set 10 | kholm-zhirkovskiy
# Processing Record 6 of Set 10 | victoria
# Processing Record 7 of Set 10 | buchanan
# Processing Record 8 of Set 10 | wa
# City not found. Skipping...
# Processing Record 9 of Set 10 | whyalla
# Processing Record 10 of Set 10 | cabinda
# Processing Record 11 of Set 10 | murindo
# Processing Record 12 of Set 10 | svetlogorsk
# Processing Record 13 of Set 10 | tiksi
# Processing Record 14 of Set 10 | kismayo
# Processing Record 15 of Set 10 | murgab
# Processing Record 16 of Set 10 | zalantun
# Processing Record 17 of Set 10 | tanjong sepat
# City not found. Skipping...
# Processing Record 18 of Set 10 | palomares
# Processing Record 19 of Set 10 | sao jose da coroa grande
# Processing Record 20 of Set 10 | tommot
# Processing Record 21 of Set 10 | barinas
# Processing Record 22 of Set 10 | samarai
# Processing Record 23 of Set 10 | abaza
# Processing Record 24 of Set 10 | yefimovskiy
# City not found. Skipping...
# Processing Record 25 of Set 10 | kasungu
# Processing Record 26 of Set 10 | cabedelo
# Processing Record 27 of Set 10 | melo
# Processing Record 28 of Set 10 | totness
# Processing Record 29 of Set 10 | port hedland
# Processing Record 30 of Set 10 | sur
# Processing Record 31 of Set 10 | hirara
# Processing Record 32 of Set 10 | korla
# Processing Record 33 of Set 10 | pakokku
# Processing Record 34 of Set 10 | bima
# Processing Record 35 of Set 10 | harer
# Processing Record 36 of Set 10 | mugur-aksy
# Processing Record 37 of Set 10 | abu samrah
# Processing Record 38 of Set 10 | zakamensk
# Processing Record 39 of Set 10 | constitucion
# Processing Record 40 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 10 | centralia
# Processing Record 42 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 10 | tarata
# Processing Record 44 of Set 10 | general pico
# Processing Record 45 of Set 10 | waterloo
# Processing Record 46 of Set 10 | sao joao da barra
# Processing Record 47 of Set 10 | diphu
# Processing Record 48 of Set 10 | barra dos coqueiros
# Processing Record 49 of Set 10 | estevan
# Processing Record 50 of Set 10 | staryy nadym
# Processing Record 1 of Set 11 | bugene
# Processing Record 2 of Set 11 | mount gambier
# Processing Record 3 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 11 | mount isa
# Processing Record 5 of Set 11 | jinchang
# Processing Record 6 of Set 11 | benoy
# Processing Record 7 of Set 11 | seoul
# Processing Record 8 of Set 11 | asau
# Processing Record 9 of Set 11 | fairbanks
# Processing Record 10 of Set 11 | bilibino
# Processing Record 11 of Set 11 | bilma
# Processing Record 12 of Set 11 | nanyuki
# Processing Record 13 of Set 11 | shirokiy
# Processing Record 14 of Set 11 | mocuba
# Processing Record 15 of Set 11 | horqueta
# Processing Record 16 of Set 11 | juneau
# Processing Record 17 of Set 11 | albanel
# Processing Record 18 of Set 11 | pitimbu
# Processing Record 19 of Set 11 | lithakia
# Processing Record 20 of Set 11 | kuruman
# Processing Record 21 of Set 11 | khorixas
# Processing Record 22 of Set 11 | phonhong
# Processing Record 23 of Set 11 | bartica
# Processing Record 24 of Set 11 | muzhi
# Processing Record 25 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 11 | aksarka
# Processing Record 27 of Set 11 | anju
# Processing Record 28 of Set 11 | mumford
# Processing Record 29 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 11 | bousso
# Processing Record 31 of Set 11 | kenai
# Processing Record 32 of Set 11 | mezen
# Processing Record 33 of Set 11 | katherine
# Processing Record 34 of Set 11 | illela
# Processing Record 35 of Set 11 | el tigre
# Processing Record 36 of Set 11 | alice springs
# Processing Record 37 of Set 11 | viedma
# Processing Record 38 of Set 11 | doha
# Processing Record 39 of Set 11 | rocha
# Processing Record 40 of Set 11 | hualmay
# Processing Record 41 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 11 | mpulungu
# Processing Record 43 of Set 11 | mandera
# Processing Record 44 of Set 11 | olenino
# Processing Record 45 of Set 11 | maldonado
# Processing Record 46 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 47 of Set 11 | naron
# Processing Record 48 of Set 11 | mosetse
# Processing Record 49 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 11 | truth or consequences
# Processing Record 1 of Set 12 | ossora
# Processing Record 2 of Set 12 | salinopolis
# Processing Record 3 of Set 12 | el alto
# Processing Record 4 of Set 12 | dubai
# Processing Record 5 of Set 12 | metkovic
# Processing Record 6 of Set 12 | derzhavinsk
# Processing Record 7 of Set 12 | bobrov
# Processing Record 8 of Set 12 | chojnow
# Processing Record 9 of Set 12 | inirida
# Processing Record 10 of Set 12 | dunedin
# Processing Record 11 of Set 12 | mega
# Processing Record 12 of Set 12 | iskilip
# Processing Record 13 of Set 12 | yanam
# Processing Record 14 of Set 12 | joensuu
# Processing Record 15 of Set 12 | vao
# Processing Record 16 of Set 12 | santa rosa
# Processing Record 17 of Set 12 | mareeba
# Processing Record 18 of Set 12 | sulangan
# Processing Record 19 of Set 12 | umm kaddadah
# Processing Record 20 of Set 12 | sokoto
# Processing Record 21 of Set 12 | sept-iles
# Processing Record 22 of Set 12 | aviles
# Processing Record 23 of Set 12 | kununurra
# Processing Record 24 of Set 12 | tura
# Processing Record 25 of Set 12 | chamalieres
# Processing Record 26 of Set 12 | sola
# Processing Record 27 of Set 12 | alto araguaia
# Processing Record 28 of Set 12 | opuwo
# Processing Record 29 of Set 12 | luanda
# Processing Record 30 of Set 12 | katsuura
# Processing Record 31 of Set 12 | ayagoz
# Processing Record 32 of Set 12 | arroio grande
# Processing Record 33 of Set 12 | mnogovershinnyy
# Processing Record 34 of Set 12 | inongo
# Processing Record 35 of Set 12 | bara
# Processing Record 36 of Set 12 | sorland
# Processing Record 37 of Set 12 | sousa
# Processing Record 38 of Set 12 | ugoofaaru
# Processing Record 39 of Set 12 | concepcion del uruguay
# Processing Record 40 of Set 12 | marrakesh
# Processing Record 41 of Set 12 | salgueiro
# Processing Record 42 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 43 of Set 12 | gisborne
# Processing Record 44 of Set 12 | yola
# Processing Record 45 of Set 12 | flinders
# Processing Record 46 of Set 12 | yelniki
# Processing Record 47 of Set 12 | portsmouth
# Processing Record 48 of Set 12 | oktyabrskiy
# Processing Record 49 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 12 | moose factory
# Processing Record 1 of Set 13 | falmouth
# Processing Record 2 of Set 13 | taiyuan
# Processing Record 3 of Set 13 | erdenet
# Processing Record 4 of Set 13 | tigil
# Processing Record 5 of Set 13 | port lincoln
# Processing Record 6 of Set 13 | yarensk
# Processing Record 7 of Set 13 | tiznit
# Processing Record 8 of Set 13 | rawson
# Processing Record 9 of Set 13 | bubaque
# Processing Record 10 of Set 13 | takoradi
# Processing Record 11 of Set 13 | lichuan
# Processing Record 12 of Set 13 | tarko-sale
# Processing Record 13 of Set 13 | mancheral
# Processing Record 14 of Set 13 | cabras
# Processing Record 15 of Set 13 | goundam
# Processing Record 16 of Set 13 | kampong thum
# Processing Record 17 of Set 13 | bealanana
# Processing Record 18 of Set 13 | dubbo
# Processing Record 19 of Set 13 | conde
# Processing Record 20 of Set 13 | khasan
# Processing Record 21 of Set 13 | helong
# Processing Record 22 of Set 13 | odesskoye
# Processing Record 23 of Set 13 | berlevag
# Processing Record 24 of Set 13 | sungairaya
# Processing Record 25 of Set 13 | traverse city
# Processing Record 26 of Set 13 | fort saint james
# Processing Record 27 of Set 13 | deputatskiy
# Processing Record 28 of Set 13 | kalmunai
# Processing Record 29 of Set 13 | ulladulla
# Processing Record 30 of Set 13 | ixtapa
# Processing Record 31 of Set 13 | kabanjahe
# Processing Record 32 of Set 13 | igrim
# Processing Record 33 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 34 of Set 13 | huarmey
# Processing Record 35 of Set 13 | pemangkat
# Processing Record 36 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 37 of Set 13 | plock
# Processing Record 38 of Set 13 | redlands
# Processing Record 39 of Set 13 | lere
# Processing Record 40 of Set 13 | maragogi
# Processing Record 41 of Set 13 | manta
# Processing Record 42 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 13 | fairview
# Processing Record 44 of Set 13 | kieta
# Processing Record 45 of Set 13 | dingle
# Processing Record 46 of Set 13 | balkanabat
# Processing Record 47 of Set 13 | natulongan
# City not found. Skipping...
# Processing Record 48 of Set 13 | sosnovoborsk
# Processing Record 49 of Set 13 | marawi
# Processing Record 50 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 14 | mangile
# City not found. Skipping...
# Processing Record 2 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 3 of Set 14 | praia da vitoria
# Processing Record 4 of Set 14 | clemencia
# Processing Record 5 of Set 14 | melilla
# Processing Record 6 of Set 14 | krivosheino
# Processing Record 7 of Set 14 | ulkan
# Processing Record 8 of Set 14 | kuusamo
# Processing Record 9 of Set 14 | maceio
# Processing Record 10 of Set 14 | panaba
# Processing Record 11 of Set 14 | neyshabur
# Processing Record 12 of Set 14 | ormara
# Processing Record 13 of Set 14 | weligama
# Processing Record 14 of Set 14 | antofagasta
# Processing Record 15 of Set 14 | umba
# Processing Record 16 of Set 14 | padang
# Processing Record 17 of Set 14 | craig
# Processing Record 18 of Set 14 | ayios kirikos
# City not found. Skipping...
# Processing Record 19 of Set 14 | dzaoudzi
# Processing Record 20 of Set 14 | jatiroto
# Processing Record 21 of Set 14 | port-gentil
# Processing Record 22 of Set 14 | esperance
# Processing Record 23 of Set 14 | van buren
# Processing Record 24 of Set 14 | demyansk
# Processing Record 25 of Set 14 | sumperk
# Processing Record 26 of Set 14 | biak
# Processing Record 27 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 14 | verkhovye
# Processing Record 29 of Set 14 | stanton
# Processing Record 30 of Set 14 | mao
# Processing Record 31 of Set 14 | dolores
# Processing Record 32 of Set 14 | ust-uda
# Processing Record 33 of Set 14 | odienne
# Processing Record 34 of Set 14 | central point
# Processing Record 35 of Set 14 | great falls
# Processing Record 36 of Set 14 | diamantino
# Processing Record 37 of Set 14 | yagodnoye
# Processing Record 38 of Set 14 | boa vista
# Processing Record 39 of Set 14 | larsnes
# Processing Record 40 of Set 14 | srednekolymsk
# Processing Record 41 of Set 14 | sohbatpur
# Processing Record 42 of Set 14 | trelew
# Processing Record 43 of Set 14 | suarez
# Processing Record 44 of Set 14 | somerville
# Processing Record 45 of Set 14 | eseka
# Processing Record 46 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 47 of Set 14 | gimli
# Processing Record 48 of Set 14 | livani
# Processing Record 49 of Set 14 | praya
# Processing Record 50 of Set 14 | qorveh
# Processing Record 1 of Set 15 | ranong
# Processing Record 2 of Set 15 | solnechnyy
# Processing Record 3 of Set 15 | bonwapitse
# Processing Record 4 of Set 15 | bansda
# City not found. Skipping...
# Processing Record 5 of Set 15 | coruripe
# Processing Record 6 of Set 15 | henties bay
# Processing Record 7 of Set 15 | ratnagiri
# Processing Record 8 of Set 15 | bend
# Processing Record 9 of Set 15 | kamyshevatskaya
# Processing Record 10 of Set 15 | cartagena
# Processing Record 11 of Set 15 | akkudah
# City not found. Skipping...
# Processing Record 12 of Set 15 | talah
# City not found. Skipping...
# Processing Record 13 of Set 15 | inhambane
# Processing Record 14 of Set 15 | ballina
# Processing Record 15 of Set 15 | atherton
# Processing Record 16 of Set 15 | sanjo
# Processing Record 17 of Set 15 | sumbe
# Processing Record 18 of Set 15 | belmonte
# Processing Record 19 of Set 15 | gangapur
# Processing Record 20 of Set 15 | wanning
# Processing Record 21 of Set 15 | koumra
# Processing Record 22 of Set 15 | kyshtovka
# Processing Record 23 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 15 | carutapera
# Processing Record 25 of Set 15 | klyuchi
# Processing Record 26 of Set 15 | husavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Shetpe  44.1667   52.1167     30.36        85         100
# 1        Rikitea -23.1203 -134.9692     78.80        72         100
# 2  Prince Rupert  54.3161 -130.3201     44.29        70           0
# 3         Avarua -21.2078 -159.7750     80.65        78          20
# 4         Albany  42.6001  -73.9662     21.16        61           5
# 5         Vanimo  -2.6741  141.3028     77.67        87          98
# 6   Saint George  37.1041 -113.5841     53.35        29           0
# 7  Pacific Grove  36.6177 -121.9166     62.31        60           0
# 8       Kot Addu  30.4692   70.9671     51.66        42           6
# 9        Ushuaia -54.8000  -68.3000     64.06        45          40
#
#    Wind Speed Current Description Country                 Date
# 0       19.53     overcast clouds      KZ  2022-02-05 18:37:32
# 1       11.70     overcast clouds      PF  2022-02-05 18:37:32
# 2       14.97           clear sky      CA  2022-02-05 18:30:10
# 3       12.66          few clouds      CK  2022-02-05 18:36:30
# 4        3.00           clear sky      US  2022-02-05 18:36:38
# 5        5.97     overcast clouds      PG  2022-02-05 18:37:33
# 6        1.01           clear sky      US  2022-02-05 18:37:34
# 7        1.99           clear sky      US  2022-02-05 18:29:19
# 8        7.36           clear sky      PK  2022-02-05 18:37:35
# 9       14.97    scattered clouds      AR  2022-02-05 18:37:35

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Shetpe      KZ  44.1667   52.1167     30.36        85         100
# 1        Rikitea      PF -23.1203 -134.9692     78.80        72         100
# 2  Prince Rupert      CA  54.3161 -130.3201     44.29        70           0
# 3         Avarua      CK -21.2078 -159.7750     80.65        78          20
# 4         Albany      US  42.6001  -73.9662     21.16        61           5
# 5         Vanimo      PG  -2.6741  141.3028     77.67        87          98
# 6   Saint George      US  37.1041 -113.5841     53.35        29           0
# 7  Pacific Grove      US  36.6177 -121.9166     62.31        60           0
# 8       Kot Addu      PK  30.4692   70.9671     51.66        42           6
# 9        Ushuaia      AR -54.8000  -68.3000     64.06        45          40
#
#    Wind Speed Current Description
# 0       19.53     overcast clouds
# 1       11.70     overcast clouds
# 2       14.97           clear sky
# 3       12.66          few clouds
# 4        3.00           clear sky
# 5        5.97     overcast clouds
# 6        1.01           clear sky
# 7        1.99           clear sky
# 8        7.36           clear sky
# 9       14.97    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
